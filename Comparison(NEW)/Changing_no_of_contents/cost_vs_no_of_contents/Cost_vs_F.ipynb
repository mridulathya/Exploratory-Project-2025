# %%
import json, heapq

# %%
with open(r"..\..\..\json\Changing_no_of_contents\QIER\QIER_75F\lr_0.001_5000iter_F75_COST_rewards_qier.json", "r") as f:
    Cost_75_qier = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\QIER\QIER_100F\lr_0.001_5000iter_F100_COST_rewards_qier.json", "r") as f:
    Cost_100_qier = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\QIER\QIER125F\lr_0.001_5000iter_F_125_COST_rewards_qier.json", "r") as f:
    Cost_125_qier = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\QIER\QIER_150F\lr_0.001_5000iter_F_150_COST_rewards_qier.json", "r") as f:
    Cost_150_qier = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\QIER\QIER_175F\lr_0.001_5000iter_F175_COST_rewards_qier.json", "r") as f:
    Cost_175_qier = heapq.nsmallest(100,json.load(f))

avg_Cost_75_qier = sum(Cost_75_qier)/len(Cost_75_qier)
avg_Cost_100_qier = sum(Cost_100_qier)/len(Cost_100_qier)
avg_Cost_125_qier = sum(Cost_125_qier)/len(Cost_125_qier)
avg_Cost_150_qier = sum(Cost_150_qier)/len(Cost_150_qier)
avg_Cost_175_qier = sum(Cost_175_qier)/len(Cost_175_qier)

# %%
with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_75F\lr_0.05_5000iter_F75_COST_rewards_FIFO.json", "r") as f:
    Cost_75_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_100F\lr_0.05_5000iter_F100_COST_rewards_FIFO.json", "r") as f:
    Cost_100_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_125F\lr_0.05_5000iter_F125_COST_rewards_FIFO.json", "r") as f:
    Cost_125_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_150F\lr_0.05_5000iter_F150_COST_rewards_FIFO.json", "r") as f:
    Cost_150_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_175F\lr_0.05_5000iter_F175_COST_rewards_FIFO.json", "r") as f:
    Cost_175_fifo = heapq.nlargest(100,json.load(f))

avg_Cost_75_fifo = sum(Cost_75_fifo)/len(Cost_75_fifo)
avg_Cost_100_fifo = sum(Cost_100_fifo)/len(Cost_100_fifo)
avg_Cost_125_fifo = sum(Cost_125_fifo)/len(Cost_125_fifo)
avg_Cost_150_fifo = sum(Cost_150_fifo)/len(Cost_150_fifo)
avg_Cost_175_fifo = sum(Cost_175_fifo)/len(Cost_175_fifo)

# %%
with open(r"..\..\..\json\Changing_no_of_contents\PER\PER_75F\500iter_F75_COST_rewards_per.json", "r") as f:
    Cost_75_per = heapq.nlargest(400,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\PER\PER_100F\500iter_F100_COST_rewards_per.json", "r") as f:
    Cost_100_per = heapq.nlargest(400,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\PER\PER_125F\500iter_F125_COST_rewards_per.json", "r") as f:
    Cost_125_per = heapq.nlargest(400,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\PER\PER_150F\500iter_F_150_COST_rewards_per.json", "r") as f:
    Cost_150_per = heapq.nlargest(400,json.load(f))
with open(r"..\..\..\json\Changing_no_of_contents\PER\PER_175F\500iter_F175_COST_rewards_per.json", "r") as f:
    Cost_175_per = heapq.nlargest(400,json.load(f))

avg_Cost_75_per = sum(Cost_75_per)/len(Cost_75_per)
avg_Cost_100_per = sum(Cost_100_per)/len(Cost_100_per)
avg_Cost_125_per = sum(Cost_125_per)/len(Cost_125_per)
avg_Cost_150_per = sum(Cost_150_per)/len(Cost_150_per)
avg_Cost_175_per = sum(Cost_175_per)/len(Cost_175_per)

# %%
with open(r"..\..\..\json\Changing_no_of_contents\LRU\LRU_75F\2000iter_75F_COST_rewards_lru.json", "r") as f:
    Cost_75_lru = json.load(f)
with open(r"..\..\..\json\Changing_no_of_contents\LRU\LRU_100F\2000iter_100F_COST_rewards_lru.json", "r") as f:
    Cost_100_lru = json.load(f)
with open(r"..\..\..\json\Changing_no_of_contents\LRU\LRU_125F\2000iter_125F_COST_rewards_lru.json", "r") as f:
    Cost_125_lru = json.load(f)
with open(r"..\..\..\json\Changing_no_of_contents\LRU\LRU_150F\2000iter_150F_COST_rewards_lru.json", "r") as f:
    Cost_150_lru = json.load(f)
with open(r"..\..\..\json\Changing_no_of_contents\LRU\LRU_175F\2000iter_175F_COST_rewards_lru.json", "r") as f:
    Cost_175_lru = json.load(f)
    
avg_Cost_75_lru = sum(Cost_75_lru)/len(Cost_75_lru)
avg_Cost_100_lru = sum(Cost_100_lru)/len(Cost_100_lru)
avg_Cost_125_lru = sum(Cost_125_lru)/len(Cost_125_lru)
avg_Cost_150_lru = sum(Cost_150_lru)/len(Cost_150_lru)
avg_Cost_175_lru = sum(Cost_175_lru)/len(Cost_175_lru)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 10,
    'font.family': 'serif',
    'axes.labelsize': 8,
    'axes.titlesize': 8,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})
plt.figure(figsize=(7,4),dpi=300)

# %%
import matplotlib.pyplot as plt


num_files = [75,100,125,150,175]

qier = [avg_Cost_75_qier, avg_Cost_100_qier, avg_Cost_125_qier, avg_Cost_150_qier, avg_Cost_175_qier]
per = [avg_Cost_75_per, avg_Cost_100_per, avg_Cost_125_per, avg_Cost_150_per, avg_Cost_175_per]
lru = [avg_Cost_75_lru, avg_Cost_100_lru, avg_Cost_125_lru, avg_Cost_150_lru, avg_Cost_175_lru]

plt.figure(figsize=(7,4),dpi=300)
# Plot styles for each method
plt.plot(num_files, qier, marker='s', linestyle='--', label='D3QN-QiER', color='dodgerblue')
plt.plot(num_files, per, marker='X', linestyle='--', label='D3QN-PER', color='darkorange')
plt.plot(num_files, lru, marker='*', linestyle='--', label='D3QN-LRU', color='limegreen')

# Labeling
plt.xlabel('Number of Files')
plt.ylabel('Average Cost for Content Retrival from CSP via Satellite')
plt.xticks(num_files) 
plt.grid(True)
plt.legend()
plt.tight_layout()

# Display
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (example placeholders – replace with real values)
num_files = [75, 100, 125, 150, 175]
qier = [avg_Cost_75_qier, avg_Cost_100_qier, avg_Cost_125_qier, avg_Cost_150_qier, avg_Cost_175_qier]
per = [avg_Cost_75_per, avg_Cost_100_per, avg_Cost_125_per, avg_Cost_150_per, avg_Cost_175_per]
lru = [avg_Cost_75_lru, avg_Cost_100_lru, avg_Cost_125_lru, avg_Cost_150_lru, avg_Cost_175_lru]

# Set IEEE-like font and style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    # "axes.labelweight": "bold",
    "axes.labelsize": 9,
    "legend.fontsize": 11,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "pdf.fonttype": 42,  # For editable text in PDF
    "ps.fonttype": 42,
})

# Bar setup
x = np.arange(len(num_files))
width = 0.25

# HD Figure
fig, ax = plt.subplots(figsize=(7.5, 4.5), dpi=300)  # High DPI for HD quality

# Plot bars
bars1 = ax.bar(x - width, qier, width, label='D3QN-QiER', color='dodgerblue', edgecolor='black')
bars2 = ax.bar(x, per, width, label='D3QN-PER', color='darkorange', edgecolor='black')
bars3 = ax.bar(x + width, lru, width, label='D3QN-LRU', color='limegreen', edgecolor='black')

# Labels
ax.set_xlabel('Number of Files', fontweight='bold')
ax.set_ylabel('Average Cost for Content Retrieval from CSP via Satellite', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=False, loc='best')

# Tight layout
fig.tight_layout()

# Save as high-res PDF (vector format) or PNG
# fig.savefig("average_cost_comparison.pdf")  # Preferred for papers
# fig.savefig("average_cost_comparison.png", dpi=600)  # For presentations

plt.show()
plt.savefig("avg_cost_vs_files.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (replace with real values)
num_files = [r"$75 $", r"$100$", r"$125$", r"$150$", r"$175$"]
qier = np.array([avg_Cost_75_qier, avg_Cost_100_qier, avg_Cost_125_qier, avg_Cost_150_qier, avg_Cost_175_qier])                                                                                                                                                                                                                                                 
per  = np.array([avg_Cost_75_per, avg_Cost_100_per, avg_Cost_125_per, avg_Cost_150_per, avg_Cost_175_per])                                                                                                                                                                                                                                                  
lru  = np.array([avg_Cost_75_lru, avg_Cost_100_lru, avg_Cost_125_lru, avg_Cost_150_lru, avg_Cost_175_lru])                                                                                                                                                                                                                                                  
fifo = np.array([avg_Cost_75_fifo, avg_Cost_100_fifo, avg_Cost_125_fifo, avg_Cost_150_fifo, avg_Cost_175_fifo])                                                                                                                                                                                                                                                 *1.5

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.175  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x - 1.5*width, qier, width, label='H-DDQN-QiER', color='gold', hatch='..', edgecolor='black')
bars2 = ax.bar(x + 0.5*width, per,  width, label='H-DDQN-PER',  color='magenta', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x + 1.5*width, lru,  width, label='H-DDQN-LRU',  color='limegreen', hatch='//', edgecolor='black')
bars4 = ax.bar(x -0.5*width, fifo, width, label='H-DDQN-FIFO', color='steelblue', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Number of contents')
ax.set_ylabel('Avg. CSP Cost')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=1, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_cost_vs_files.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('No. of contents')
ax.set_ylabel('Avg. CSP cost')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
# plt.savefig("avg_chr_vs_transmission_capacity_linegraph.png", dpi=300)

# %%
x,y,z,p =0,0,0,0
for i,j,k,l in zip(qier,per,lru,fifo):
    x += (i-j)/j
    y += (i-k)/k
    p += (i-l)/l
print(x/len(qier)*100, y/len(per)*100 , p/len(fifo)*100)
# Out:
# -52.33303595162144 -52.23647619429981 -35.57401507483744

# %%
with open(r"D:\IIT-BHU Engg\CSE-SEM4\EXPLO\Heuristic Final\F75_QIER\5000iter_F75_COST_rewards_qier.json", "r") as f:
    Cost_75_qier = json.load(f)

# %%
plt.figure(figsize=(10, 5),dpi=500)
plt.plot(Cost_75_qier, marker='o', linestyle='-', color='teal')
plt.title('Original Cost Over Episodes')
plt.xlabel('Steps or Episodes')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler,MinMaxScaler,StandardScaler,QuantileTransformer
import numpy as np
import matplotlib.pyplot as plt

# Convert to 2D array as required by sklearn
cost_array = np.array(Cost_75_qier).reshape(-1, 1)

# Apply RobustScaler
scaler = MinMaxScaler()
cost_scaled = scaler.fit_transform(cost_array)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(cost_scaled, marker='o', linestyle='-', color='orange')
plt.title('Cost After Robust Scaling')
plt.xlabel('Steps or Episodes')
plt.ylabel('Scaled Cost')
plt.grid(True)
plt.show()
