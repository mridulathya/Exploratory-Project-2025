# %%
import json

# %%
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_1\QiER\lr_0.001_5000iter_L1_CHR_rewards_qier.json", "r") as f:
    CHR_75_qier = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_2\QiER\lr_0.001_5000iter_L2_CHR_rewards_qier.json", "r") as f:
    CHR_100_qier = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_4\QiER\lr_0.001_5000iter_L4_CHR_rewards_qier.json", "r") as f:
    CHR_125_qier = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_5\QiER\lr_0.001_5000iter_L5_CHR_rewards_qier.json", "r") as f:
    CHR_150_qier = json.load(f)
# with open(r"D:\IIT-BHU Engg\CSE-SEM4\EXPLO\Final_Project_Code\F175_QIER\5000iter175F_cost_rewards_qierCHR150F.json", "r") as f:
#     CHR_175_qier = json.load(f)

CHR_75_qier = sum(CHR_75_qier)/len(CHR_75_qier)
CHR_100_qier = sum(CHR_100_qier)/len(CHR_100_qier)
CHR_125_qier = sum(CHR_125_qier)/len(CHR_125_qier)
CHR_150_qier = sum(CHR_150_qier)/len(CHR_150_qier)
# CHR_175_qier = sum(CHR_175_qier)/len(CHR_175_qier)

# %%
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_1\QiER\lr_0.001_5000iter_L1_CHR_rewards_qier.json", "r") as f:
    CHR_75_per = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_1\QiER\lr_0.001_5000iter_L1_CHR_rewards_qier.json", "r") as f:
    CHR_100_per = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_4\PER\500iter_L4_CHR_rewards_per.json", "r") as f:
    CHR_125_per = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_5\PER\500iter_L5_CHR_rewards_per.json", "r") as f:
    CHR_150_per = json.load(f)
# with open(r"D:\IIT-BHU Engg\CSE-SEM4\EXPLO\Final_Project_Code\F175_PER\2000iter_F_175_CHR_rewards_per.json", "r") as f:
#     CHR_175_per = json.load(f)

CHR_75_per = sum(CHR_75_per)/len(CHR_75_per)
CHR_100_per = sum(CHR_100_per)/len(CHR_100_per)
CHR_125_per = sum(CHR_125_per)/len(CHR_125_per)
CHR_150_per = sum(CHR_150_per)/len(CHR_150_per)
# CHR_175_per = sum(CHR_175_per)/len(CHR_175_per)

# %%
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_1\LRU\2000iter_L1_CHR_rewards_lru.json", "r") as f:
    CHR_75_lru = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_2\LRU\2000iter_L2_CHR_rewards_lru.json", "r") as f:
    CHR_100_lru = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_4\LRU\2000iter_L4_CHR_rewards_lru.json", "r") as f:
    CHR_125_lru = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_5\LRU\2000iter_L5_CHR_rewards_lru.json", "r") as f:
    CHR_150_lru = json.load(f)
# with open(r"D:\IIT-BHU Engg\CSE-SEM4\EXPLO\Final_Project_Code\F175_LRU\2000iter_175F_CHR_rewards_lru.json", "r") as f:
#     CHR_175_lru = json.load(f)
    
CHR_75_lru = sum(CHR_75_lru)/len(CHR_75_lru)
CHR_100_lru = sum(CHR_100_lru)/len(CHR_100_lru)
CHR_125_lru = sum(CHR_125_lru)/len(CHR_125_lru)
CHR_150_lru = sum(CHR_150_lru)/len(CHR_150_lru)
# CHR_175_lru = sum(CHR_175_lru)/len(CHR_175_lru)

# %%
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_1\FIFO\lr_0.05_5000iter_L1_CHR_rewards_FIFO.json", "r") as f:
    Cost_75_fifo = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_2\FIFO\lr_0.05_5000iter_L2_CHR_rewards_FIFO.json", "r") as f:
    Cost_100_fifo = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_4\FIFO\lr_0.05_5000iter_L4_CHR_rewards_FIFO.json", "r") as f:
    Cost_125_fifo = json.load(f)
with open(r"..\..\..\json\Changing_transimission_Capacity\L_Fprime_5\FIFO\lr_0.05_5000iter_L5_CHR_rewards_FIFO.json", "r") as f:
    Cost_150_fifo = json.load(f)
# with open(r"..\..\..\json\Changing_no_of_contents\FIFO\FIFO_175F\lr_0.05_5000iter_F175_COST_rewards_FIFO.json", "r") as f:
#     Cost_175_fifo = json.load(f)

avg_Cost_75_fifo = sum(Cost_75_fifo)/len(Cost_75_fifo)
avg_Cost_100_fifo = sum(Cost_100_fifo)/len(Cost_100_fifo)
avg_Cost_125_fifo = sum(Cost_125_fifo)/len(Cost_125_fifo)
avg_Cost_150_fifo = sum(Cost_150_fifo)/len(Cost_150_fifo)
# avg_Cost_175_fifo = sum(Cost_175_fifo)/len(Cost_175_fifo)

# %%
import matplotlib.pyplot as plt


num_files = ["F'","F'/2","F'/4","F'/5"]

qier = [CHR_75_qier, CHR_100_qier, CHR_125_qier, CHR_150_qier]
per = [CHR_75_per, CHR_100_per, CHR_125_per, CHR_150_per]
lru = [CHR_75_lru, CHR_100_lru, CHR_125_lru, CHR_150_lru]
fifo = [avg_Cost_75_fifo, avg_Cost_100_fifo, avg_Cost_125_fifo, avg_Cost_150_fifo]

# plt.figure(figsize=(12,6))
# Plot styles for each method
plt.plot(num_files, qier, marker='s', linestyle='--', label='D3QN-QiER', color='dodgerblue')
plt.plot(num_files, per, marker='X', linestyle='--', label='D3QN-PER', color='darkorange')
plt.plot(num_files, lru, marker='*', linestyle='--', label='D3QN-LRU', color='limegreen')
plt.plot(num_files, fifo, marker='o', linestyle='--', label='D3QN-FIFO', color='limegreen')

# Labeling
plt.xlabel('Number of Files')
plt.ylabel('Cache hit ratio')
plt.xticks(num_files) 
plt.grid(True)
plt.legend()
plt.tight_layout()

# Display
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.2  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x - 1.5*width, qier, width, label='H-DDQN-QiER', color='gold', hatch='..', edgecolor='black')
bars2 = ax.bar(x + 0.5*width, per,  width, label='H-DDQN-PER',  color='magenta', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x + 1.5*width, lru,  width, label='H-DDQN-LRU',  color='limegreen', hatch='//', edgecolor='black')
bars4 = ax.bar(x -0.5*width, fifo, width, label='H-DDQN-FIFO', color='steelblue', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Transmission capacity')
ax.set_ylabel('Avg. cache hit ratio')
ax.set_xticks(x)
ax.set_ylim(0.6,1.0)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=False, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_CHR_vs_transmission_capacity.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('Cache capacity')
ax.set_ylabel('Avg. System regret')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_chr_vs_capacity_linegraph.png", dpi=300)
