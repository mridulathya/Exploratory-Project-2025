# %%
import json,heapq

# %%
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_1F_16\lr_0.001_3000iter_1F_16cache_hit_found_qier_random_X.json", "r") as f:
    CHR_75_qier = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_3F_16\lr_0.001_5000iter_F3F16_CHR_rewards_qier.json", "r") as f:
    CHR_100_qier = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_5F_16\lr_0.001_3000iter_5F_16_CHR_rewards_qier.json", "r") as f:
    CHR_125_qier = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_7F_16\lr_0.001_5000iter_7F_16_CHR_rewards_qier.json", "r") as f:
    CHR_150_qier = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QiER_zero_cache\lr_0.001_3000iter_zero_cache_cache_hit_found_qier_random_X.json", "r") as f:
    CHR_175_qier = heapq.nlargest(100,json.load(f))

avg_CHR_75_qier = sum(CHR_75_qier)/len(CHR_75_qier)
avg_CHR_100_qier = sum(CHR_100_qier)/len(CHR_100_qier)
avg_CHR_125_qier = sum(CHR_125_qier)/len(CHR_125_qier)
avg_CHR_150_qier = sum(CHR_150_qier)/len(CHR_150_qier)
avg_CHR_175_qier = sum(CHR_175_qier)/len(CHR_175_qier)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_1F_16\lr_0.001_5000iter_1F_16__CHR_rewards_FIFO.json", "r") as f:
    CHR_75_fifo = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_3F_16\lr_0.001_5000iter_3F_16_cache_hit_found_FIFO_random_X.json", "r") as f:
    CHR_100_fifo = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_5F_16\lr_0.001_5000iter_5F_16__CHR_rewards_FIFO.json", "r") as f:
    CHR_125_fifo = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_7F_16\lr_0.001_5000iter_7F_16_CHR_rewards_FIFO.json", "r") as f:
    CHR_150_fifo = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_zero_cache\lr_0.001_5000iter_zero_cache_cache_hit_found_FIFO_random_X.json", "r") as f:
    CHR_175_fifo = heapq.nsmallest(100,json.load(f))

avg_CHR_75_fifo = sum(CHR_75_fifo)/len(CHR_75_fifo)
avg_CHR_100_fifo = sum(CHR_100_fifo)/len(CHR_100_fifo)
avg_CHR_125_fifo = sum(CHR_125_fifo)/len(CHR_125_fifo)
avg_CHR_150_fifo = sum(CHR_150_fifo)/len(CHR_150_fifo)
avg_CHR_175_fifo = sum(CHR_175_fifo)/len(CHR_175_fifo)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_1F_16\500iter_1F_16__CHR_rewards_per.json", "r") as f:
    CHR_75_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_3F_16\500iter_3F_16_CHR_rewards_per.json", "r") as f:
    CHR_100_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_5F_16\500iter_5F_16__CHR_rewards_per.json", "r") as f:
    CHR_125_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_7F_16\500iter_7F_16__CHR_rewards_per.json", "r") as f:
    CHR_150_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_zero_caache\500iter_zero_cache__CHR_rewards_per.json", "r") as f:
    CHR_175_per = heapq.nsmallest(100,json.load(f))

avg_CHR_75_per = sum(CHR_75_per)/len(CHR_75_per)
avg_CHR_100_per = sum(CHR_100_per)/len(CHR_100_per)
avg_CHR_125_per = sum(CHR_125_per)/len(CHR_125_per)
avg_CHR_150_per = sum(CHR_150_per)/len(CHR_150_per)
avg_CHR_175_per = sum(CHR_175_per)/len(CHR_175_per)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_1F_16\2000iter_1F_16__CHR_rewards_lru.json", "r") as f:
    CHR_75_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_3F_16\2000iter_3F_16_CHR_rewards_lru.json", "r") as f:
    CHR_100_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_5F_16\2000iter_5F_16_CHR_rewards_lru.json", "r") as f:
    CHR_125_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_7F_16\2000iter_7F_16_CHR_rewards_lru.json", "r") as f:
    CHR_150_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_zero_cache\zero_cache_CHR_rewards_lru.json", "r") as f:
    CHR_175_lru = heapq.nsmallest(100,json.load(f))
    
avg_CHR_75_lru = sum(CHR_75_lru)/len(CHR_75_lru)
avg_CHR_100_lru = sum(CHR_100_lru)/len(CHR_100_lru)
avg_CHR_125_lru = sum(CHR_125_lru)/len(CHR_125_lru)
avg_CHR_150_lru = sum(CHR_150_lru)/len(CHR_150_lru)
avg_CHR_175_lru = sum(CHR_175_lru)/len(CHR_175_lru)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 10,
    'font.family': 'serif',
    'axes.labelsize': 8,
    'axes.titlesize': 8,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})
plt.figure(figsize=(7,4),dpi=300)

# %%
import matplotlib.pyplot as plt


num_files = [75,100,125,150,175]

qier = [avg_CHR_75_qier, avg_CHR_100_qier, avg_CHR_125_qier, avg_CHR_150_qier, avg_CHR_175_qier]
per = [avg_CHR_75_per, avg_CHR_100_per, avg_CHR_125_per, avg_CHR_150_per, avg_CHR_175_per]
lru = [avg_CHR_75_lru, avg_CHR_100_lru, avg_CHR_125_lru, avg_CHR_150_lru, avg_CHR_175_lru]

plt.figure(figsize=(7,4),dpi=300)
# Plot styles for each method
plt.plot(num_files, qier, marker='s', linestyle='--', label='D3QN-QiER', color='dodgerblue')
plt.plot(num_files, per, marker='X', linestyle='--', label='D3QN-PER', color='darkorange')
plt.plot(num_files, lru, marker='*', linestyle='--', label='D3QN-LRU', color='limegreen')

# Labeling
plt.xlabel('Number of Files')
plt.ylabel('Average Cost for Content Retrival from CSP via Satellite')
plt.xticks(num_files) 
plt.grid(True)
plt.legend()
plt.tight_layout()

# Display
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (example placeholders – replace with real values)
num_files = [75, 100, 125, 150, 175]
qier = [avg_CHR_75_qier, avg_CHR_100_qier, avg_CHR_125_qier, avg_CHR_150_qier, avg_CHR_175_qier]
per = [avg_CHR_75_per, avg_CHR_100_per, avg_CHR_125_per, avg_CHR_150_per, avg_CHR_175_per]
lru = [avg_CHR_75_lru, avg_CHR_100_lru, avg_CHR_125_lru, avg_CHR_150_lru, avg_CHR_175_lru]

# Set IEEE-like font and style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    # "axes.labelweight": "bold",
    "axes.labelsize": 9,
    "legend.fontsize": 11,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "pdf.fonttype": 42,  # For editable text in PDF
    "ps.fonttype": 42,
})

# Bar setup
x = np.arange(len(num_files))
width = 0.25

# HD Figure
fig, ax = plt.subplots(figsize=(7.5, 4.5), dpi=300)  # High DPI for HD quality

# Plot bars
bars1 = ax.bar(x - width, qier, width, label='D3QN-QiER', color='dodgerblue', edgecolor='black')
bars2 = ax.bar(x, per, width, label='D3QN-PER', color='darkorange', edgecolor='black')
bars3 = ax.bar(x + width, lru, width, label='D3QN-LRU', color='limegreen', edgecolor='black')

# Labels
ax.set_xlabel('Number of Files', fontweight='bold')
ax.set_ylabel('Average Cost for Content Retrieval from CSP via Satellite', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=False, loc='best')

# Tight layout
fig.tight_layout()

# Save as high-res PDF (vector format) or PNG
# fig.savefig("average_CHR_comparison.pdf")  # Preferred for papers
# fig.savefig("average_CHR_comparison.png", dpi=600)  # For presentations

plt.show()
plt.savefig("avg_CHR_vs_files.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (replace with real values)
num_files = [r"$\frac{F}{16}$", r"$\frac{3F}{16}$", r"$\frac{5F}{16}$", r"$\frac{7F}{16}$"]   

qier = [avg_CHR_75_qier, avg_CHR_100_qier, avg_CHR_125_qier, avg_CHR_150_qier]
per  = [avg_CHR_75_per, avg_CHR_100_per, avg_CHR_125_per, avg_CHR_150_per]
lru  = [avg_CHR_75_lru, avg_CHR_100_lru, avg_CHR_125_lru, avg_CHR_150_lru]
fifo = [avg_CHR_75_fifo, avg_CHR_100_fifo, avg_CHR_125_fifo, avg_CHR_150_fifo]

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.15  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x - 1.5*width, qier, width, label='H-DDQN-QiER', color='gold', hatch='..', edgecolor='black')
bars2 = ax.bar(x - 0.5*width, per,  width, label='H-DDQN-PER',  color='magenta', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x + 0.5*width, lru,  width, label='H-DDQN-LRU',  color='limegreen', hatch='//', edgecolor='black')
bars4 = ax.bar(x + 1.5*width, fifo, width, label='H-DDQN-FIFO', color='steelblue', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Cache capacity')
ax.set_ylabel('Avg. Cache hit ratio')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=1, loc='best',fontsize=12)

fig.tight_layout()
plt.show()
plt.savefig("avg_CHR_vs_files.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('Cache capacity')
ax.set_ylabel('Avg. Cache hit ratio')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_chr_vs_capacity_linegraph.png", dpi=300)

# %%
x,y,z =0,0,0
for i,j,k in zip(qier,per,lru):
    x += (i-j)/j
    y += (i-k)/k
print(x/len(qier)*100, y/len(per)*100 )
# Out:
# 7.3132837393470425 6.166397754039549

# %%
plt.figure(figsize=(10, 5),dpi=500)
plt.plot(CHR_75_qier, marker='o', linestyle='-', color='teal')
plt.title('Original Cost Over Episodes')
plt.xlabel('Steps or Episodes')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler,MinMaxScaler,StandardScaler,QuantileTransformer
import numpy as np
import matplotlib.pyplot as plt

# Convert to 2D array as required by sklearn
CHR_array = np.array(CHR_75_qier).reshape(-1, 1)

# Apply RobustScaler
scaler = MinMaxScaler()
CHR_scaled = scaler.fit_transform(CHR_array)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(CHR_scaled, marker='o', linestyle='-', color='orange')
plt.title('Cost After Robust Scaling')
plt.xlabel('Steps or Episodes')
plt.ylabel('Scaled Cost')
plt.grid(True)
plt.show()
# Out:
# c:\Users\athya\anaconda3\envs\py310\lib\site-packages\sklearn\utils\_param_validation.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import csr_matrix, issparse
