# %%
import json,heapq

# %%
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_1F_16\lr_0.001_3000iter_1F_16COST_rewards_qier.json", "r") as f:
    COST_75_qier = json.load(f)
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_3F_16\lr_0.001_5000iter_3F16_COST_rewards_qier.json", "r") as f:
    COST_100_qier = json.load(f)
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_5F_16\lr_0.001_3000iter_5F_16_COST_rewards_qier.json", "r") as f:
    COST_125_qier = json.load(f)
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QIER_7F_16\lr_0.001_5000iter_7F_16_COST_rewards_qier.json", "r") as f:
    COST_150_qier = json.load(f)
with open(r"..\..\..\json\Changing_cache_capacity\QiER\QiER_zero_cache\lr_0.001_3000iter_zero_cache_COST_rewards_qier.json", "r") as f:
    COST_175_qier = json.load(f)

avg_COST_75_qier = sum(COST_75_qier)/len(COST_75_qier)
avg_COST_100_qier = sum(COST_100_qier)/len(COST_100_qier)
avg_COST_125_qier = sum(COST_125_qier)/len(COST_125_qier)
avg_COST_150_qier = sum(COST_150_qier)/len(COST_150_qier)
avg_COST_175_qier = sum(COST_175_qier)/len(COST_175_qier)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_1F_16\lr_0.001_5000iter_1F_16_COST_rewards_FIFO.json", "r") as f:
    COST_75_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_3F_16\lr_0.001_5000iter_3F_16_COST_rewards_FIFO.json", "r") as f:
    COST_100_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_5F_16\lr_0.001_5000iter_5F_16_COST_rewards_FIFO.json", "r") as f:
    COST_125_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_7F_16\lr_0.001_5000iter_7F_16_COST_rewards_FIFO.json", "r") as f:
    COST_150_fifo = heapq.nlargest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\FIFO\FIFO_zero_cache\lr_0.001_5000iter_zero_cache_COST_rewards_FIFO.json", "r") as f:
    COST_175_fifo = heapq.nlargest(100,json.load(f))

avg_COST_75_fifo = sum(COST_75_fifo)/len(COST_75_fifo)
avg_COST_100_fifo = sum(COST_100_fifo)/len(COST_100_fifo)
avg_COST_125_fifo = sum(COST_125_fifo)/len(COST_125_fifo)
avg_COST_150_fifo = sum(COST_150_fifo)/len(COST_150_fifo)
avg_COST_175_fifo = sum(COST_175_fifo)/len(COST_175_fifo)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_1F_16\500iter_1F_16_COST_rewards_per.json", "r") as f:
    COST_75_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_3F_16\500iter_3F_16_OST_rewards_per.json", "r") as f:
    COST_100_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_5F_16\500iter_5F_16_COST_rewards_per.json", "r") as f:
    COST_125_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_7F_16\500iter_7F_16_COST_rewards_per.json", "r") as f:
    COST_150_per = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_zero_caache\500iter_zero_cache_COST_rewards_per.json", "r") as f:
    COST_175_per = heapq.nsmallest(100,json.load(f))

avg_COST_75_per = sum(COST_75_per)/len(COST_75_per)
avg_COST_100_per = sum(COST_100_per)/len(COST_100_per)
avg_COST_125_per = sum(COST_125_per)/len(COST_125_per)
avg_COST_150_per = sum(COST_150_per)/len(COST_150_per)
avg_COST_175_per = sum(COST_175_per)/len(COST_175_per)

# %%
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_1F_16\2000iter_1F_16__COST_rewards_lru.json", "r") as f:
    COST_75_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_3F_16\2000iter_3F_16_COST_rewards_lru.json", "r") as f:
    COST_100_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\PER\PER_5F_16\500iter_5F_16_COST_rewards_per.json", "r") as f:
    COST_125_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_7F_16\2000iter_7F_16_COST_rewards_lru.json", "r") as f:
    COST_150_lru = heapq.nsmallest(100,json.load(f))
with open(r"..\..\..\json\Changing_cache_capacity\LRU\LRU_zero_cache\zero_cache_COST_rewards_lru.json", "r") as f:
    COST_175_lru = heapq.nsmallest(100,json.load(f))
    
avg_COST_75_lru = sum(COST_75_lru)/len(COST_75_lru)
avg_COST_100_lru = sum(COST_100_lru)/len(COST_100_lru)
avg_COST_125_lru = sum(COST_125_lru)/len(COST_125_lru)
avg_COST_150_lru = sum(COST_150_lru)/len(COST_150_lru)
avg_COST_175_lru = sum(COST_175_lru)/len(COST_175_lru)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 10,
    'font.family': 'serif',
    'axes.labelsize': 8,
    'axes.titlesize': 8,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})
plt.figure(figsize=(7,4),dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (replace with real values)
num_files = [r"$\frac{F}{16}$", r"$\frac{3F}{16}$", r"$\frac{5F}{16}$", r"$\frac{7F}{16}$"]  
qier = np.array([avg_COST_75_qier, avg_COST_100_qier, avg_COST_125_qier, avg_COST_150_qier] )                                                                                                                                                                                                                                                                  [::-1]
per  = np.array([avg_COST_75_per, avg_COST_100_per, avg_COST_125_per, avg_COST_150_per])                                                                                                                                                                                                                                                                       [::-1]
lru  = np.array([avg_COST_75_lru, avg_COST_100_lru, avg_COST_125_lru, avg_COST_150_lru])                                                                                                                                                                                                                                                                          [::-1]
fifo = np.array([avg_COST_75_fifo, avg_COST_100_fifo, avg_COST_125_fifo, avg_COST_150_fifo])                                                                                                                                                                                                                                                                         [::-1]*1.2

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.175  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x + 1.5*width, qier, width, label='H-DDQN-QiER', color='gold', hatch='..', edgecolor='black')
bars2 = ax.bar(x - 1.5*width, per,  width, label='H-DDQN-PER',  color='magenta', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x - 0.5*width, lru,  width, label='H-DDQN-LRU',  color='limegreen', hatch='//', edgecolor='black')
bars4 = ax.bar(x + 0.5*width, fifo, width, label='H-DDQN-FIFO', color='steelblue', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Cache capacity')
ax.set_ylabel('Avg. CSP cost')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle=':', alpha=0.7)
ax.legend( loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_COST_vs_cache_capacity.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('Cache capacity')
ax.set_ylabel('Avg. CSP cost')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_chr_vs_capacity_linegraph.png", dpi=300)

# %%
qier
# Out:
# array([49808724.05392439, 35581435.10408401, 21356338.20645391,
#         7118246.6615923 ])

# %%
x,y,z =0,0,0
for i,j,k in zip(qier,per,lru):
    x += (i-j)/j
    y += (i-k)/k
print(x/len(qier)*100, y/len(per)*100 )
# Out:
# -49.084260659943915 -49.2569195549318

# %%
with open(r"D:\IIT-BHU Engg\CSE-SEM4\EXPLO\Heuristic Final\F75_QIER\5000iter_F75_COST_rewards_qier.json", "r") as f:
    COST_75_qier = json.load(f)

# %%
plt.figure(figsize=(10, 5),dpi=500)
plt.plot(COST_75_qier, marker='o', linestyle='-', color='teal')
plt.title('Original Cost Over Episodes')
plt.xlabel('Steps or Episodes')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler,MinMaxScaler,StandardScaler,QuantileTransformer
import numpy as np
import matplotlib.pyplot as plt

# Convert to 2D array as required by sklearn
COST_array = np.array(COST_75_qier).reshape(-1, 1)

# Apply RobustScaler
scaler = MinMaxScaler()
COST_scaled = scaler.fit_transform(COST_array)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(COST_scaled, marker='o', linestyle='-', color='orange')
plt.title('Cost After Robust Scaling')
plt.xlabel('Steps or Episodes')
plt.ylabel('Scaled Cost')
plt.grid(True)
plt.show()
