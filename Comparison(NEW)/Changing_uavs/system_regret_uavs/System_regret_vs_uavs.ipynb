# %%
import json, heapq

# %%
with open(r"..\..\..\json\Changing_uavs\U8\QiER\lr_0.001_5000iter_F100_Systemregret_rewards_qier.json", "r") as f:
    Systemregret_75_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\QiER\lr_0.001_5000iter_F100_Systemregret_rewards_qier.json", "r") as f:
    Systemregret_100_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\QiER\lr_0.001_5000iter_F100_Systemregret_rewards_qier.json", "r") as f:
    Systemregret_125_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\QiER\lr_0.001_5000iter_F100_Systemregret_rewards_qier (1).json", "r") as f:
    Systemregret_150_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\QiER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_175_qier = json.load(f)

avg_Systemregret_75_qier = sum(Systemregret_75_qier)/len(Systemregret_75_qier)
avg_Systemregret_100_qier = sum(Systemregret_100_qier)/len(Systemregret_100_qier)
avg_Systemregret_125_qier = sum(Systemregret_125_qier)/len(Systemregret_125_qier)
avg_Systemregret_150_qier = sum(Systemregret_150_qier)/len(Systemregret_150_qier)
avg_Systemregret_175_qier = sum(Systemregret_175_qier)/len(Systemregret_175_qier)

# %%
with open(r"..\..\..\json\Changing_uavs\U8\FIFO\lr_0.05_5000iter_F100_Systemregret_rewards_FIFO.json", "r") as f:
    Systemregret_75_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\FIFO\lr_0.05_5000iter_F100_Systemregret_rewards_FIFO.json", "r") as f:
    Systemregret_100_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\FIFO\lr_0.05_5000iter_F100_Systemregret_rewards_FIFO (2).json", "r") as f:
    Systemregret_125_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\FIFO\lr_0.05_5000iter_F100_Systemregret_rewards_FIFO.json", "r") as f:
    Systemregret_150_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\FIFO\lr_0.05_5000iter_F100_Systemregret_rewards_FIFO.json", "r") as f:
    Systemregret_175_fifo = json.load(f)

avg_Systemregret_75_fifo = sum(Systemregret_75_fifo)/len(Systemregret_75_fifo)
avg_Systemregret_100_fifo = sum(Systemregret_100_fifo)/len(Systemregret_100_fifo)
avg_Systemregret_125_fifo = sum(Systemregret_125_fifo)/len(Systemregret_125_fifo)
avg_Systemregret_150_fifo = sum(Systemregret_150_fifo)/len(Systemregret_150_fifo)
avg_Systemregret_175_fifo = sum(Systemregret_175_fifo)/len(Systemregret_175_fifo)

# %%
with open(r"..\..\..\json\Changing_uavs\U8\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_75_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_100_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_125_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_150_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_175_per = json.load(f)

avg_Systemregret_75_per = sum(Systemregret_75_per)/len(Systemregret_75_per)
avg_Systemregret_100_per = sum(Systemregret_100_per)/len(Systemregret_100_per)
avg_Systemregret_125_per = sum(Systemregret_125_per)/len(Systemregret_125_per)
avg_Systemregret_150_per = sum(Systemregret_150_per)/len(Systemregret_150_per)
avg_Systemregret_175_per = sum(Systemregret_175_per)/len(Systemregret_175_per)

# %%
with open(r"..\..\..\json\Changing_uavs\U16\PER\500iter_F75_Systemregret_rewards_per.json", "r") as f:
    Systemregret_75_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\LRU\2000iter_100F_Systemregret_rewards_lru.json", "r") as f:
    Systemregret_100_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\LRU\2000iter_100F_Systemregret_rewards_lru.json", "r") as f:
    Systemregret_125_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\LRU\2000iter_100F_Systemregret_rewards_lru.json", "r") as f:
    Systemregret_150_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\LRU\2000iter_100F_Systemregret_rewards_lru.json", "r") as f:
    Systemregret_175_lru = json.load(f)
    
avg_Systemregret_75_lru = sum(Systemregret_75_lru)/len(Systemregret_75_lru)
avg_Systemregret_100_lru = sum(Systemregret_100_lru)/len(Systemregret_100_lru)
avg_Systemregret_125_lru = sum(Systemregret_125_lru)/len(Systemregret_125_lru)
avg_Systemregret_150_lru = sum(Systemregret_150_lru)/len(Systemregret_150_lru)
avg_Systemregret_175_lru = sum(Systemregret_175_lru)/len(Systemregret_175_lru)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 10,
    'font.family': 'serif',
    'axes.labelsize': 8,
    'axes.titlesize': 8,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})
plt.figure(figsize=(7,4),dpi=300)

# %%
import matplotlib.pyplot as plt


num_files = [75,100,125,150,175]

qier = [avg_Systemregret_75_qier, avg_Systemregret_100_qier, avg_Systemregret_125_qier, avg_Systemregret_150_qier, avg_Systemregret_175_qier]
per = [avg_Systemregret_75_per, avg_Systemregret_100_per, avg_Systemregret_125_per, avg_Systemregret_150_per, avg_Systemregret_175_per]
lru = [avg_Systemregret_75_lru, avg_Systemregret_100_lru, avg_Systemregret_125_lru, avg_Systemregret_150_lru, avg_Systemregret_175_lru]

plt.figure(figsize=(7,4),dpi=300)
# Plot styles for each method
plt.plot(num_files, qier, marker='s', linestyle='--', label='D3QN-QiER', color='dodgerblue')
plt.plot(num_files, per, marker='X', linestyle='--', label='D3QN-PER', color='darkorange')
plt.plot(num_files, lru, marker='*', linestyle='--', label='D3QN-LRU', color='limegreen')

# Labeling
plt.xlabel('Number of Files')
plt.ylabel('Average Cost for Content Retrival from CSP via Satellite')
plt.xticks(num_files) 
plt.grid(True)
plt.legend()
plt.tight_layout()

# Display
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (example placeholders – replace with real values)
num_files = [75, 100, 125, 150, 175]
qier = [avg_Systemregret_75_qier, avg_Systemregret_100_qier, avg_Systemregret_125_qier, avg_Systemregret_150_qier, avg_Systemregret_175_qier]
per = [avg_Systemregret_75_per, avg_Systemregret_100_per, avg_Systemregret_125_per, avg_Systemregret_150_per, avg_Systemregret_175_per]
lru = [avg_Systemregret_75_lru, avg_Systemregret_100_lru, avg_Systemregret_125_lru, avg_Systemregret_150_lru, avg_Systemregret_175_lru]

# Set IEEE-like font and style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    # "axes.labelweight": "bold",
    "axes.labelsize": 9,
    "legend.fontsize": 11,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "pdf.fonttype": 42,  # For editable text in PDF
    "ps.fonttype": 42,
})

# Bar setup
x = np.arange(len(num_files))
width = 0.25

# HD Figure
fig, ax = plt.subplots(figsize=(7.5, 4.5), dpi=300)  # High DPI for HD quality

# Plot bars
bars1 = ax.bar(x - width, qier, width, label='D3QN-QiER', color='dodgerblue', edgecolor='black')
bars2 = ax.bar(x, per, width, label='D3QN-PER', color='darkorange', edgecolor='black')
bars3 = ax.bar(x + width, lru, width, label='D3QN-LRU', color='limegreen', edgecolor='black')

# Labels
ax.set_xlabel('Number of Files', fontweight='bold')
ax.set_ylabel('Average Cost for Content Retrieval from CSP via Satellite', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(num_files)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=False, loc='best')

# Tight layout
fig.tight_layout()

# Save as high-res PDF (vector format) or PNG
# fig.savefig("average_Systemregret_comparison.pdf")  # Preferred for papers
# fig.savefig("average_Systemregret_comparison.png", dpi=600)  # For presentations

plt.show()
plt.savefig("avg_Systemregret_vs_files.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np


qier = [avg_Systemregret_75_qier, avg_Systemregret_100_qier,   avg_Systemregret_150_qier, avg_Systemregret_175_qier]
per  = [avg_Systemregret_75_per, avg_Systemregret_100_per, avg_Systemregret_150_per, avg_Systemregret_175_per]
lru  = [avg_Systemregret_75_lru, avg_Systemregret_100_lru, avg_Systemregret_150_lru, avg_Systemregret_175_lru]
fifo = [avg_Systemregret_75_fifo, avg_Systemregret_100_fifo,   avg_Systemregret_150_fifo, avg_Systemregret_175_fifo]

# Data (replace with real values)
num_files = [r"$8$", r"$10$", r"$14$", r"$16$"]                                                                                                                                                                                                                                                                                                    ;lru, qier = qier, lru
# Fonts and layout

plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.15  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x + 1.5*width, qier, width, label='H-DDQN-QiER', color='#ffb000', hatch='..', edgecolor='black')
bars2 = ax.bar(x + 0.5*width, per,  width, label='H-DDQN-PER',  color='#dc267f', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x - 0.5*width, lru,  width, label='H-DDQN-LRU',  color='#648fff', hatch='//', edgecolor='black')
bars4 = ax.bar(x -1.5*width, fifo, width, label='H-DDQN-FIFO', color='#00b386', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Number of UAVs')
ax.set_ylabel('Avg. System regret')
ax.set_xticks(x)
ax.set_xticklabels(num_files)
# ax.set_ylim(0.7, 1.0)  

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=1, loc='best',fontsize=14)

fig.tight_layout()
plt.show()
plt.savefig("avg_Systemregret_vs_uavs.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('Number of UAVs')
ax.set_ylabel('Avg. system regret')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_cost_vs_uavs_linegraph.png", dpi=300)

# %%
max(Systemregret_75_lru)
# Out:
# 0.4841586438074573

# %%
Systemregret_100_qier
# Out:
# [0.5463389293525902,
#  0.5193322721042918,
#  0.5625303443431549,
#  0.5129905163818642,
#  0.5101177921059886,
#  0.5558199636946477,
#  0.4603767545969667,
#  0.5110284246434216,
#  0.44341731231012904,
#  0.5012715487635881,
#  0.49720629374153696,
#  0.49529749484435187,
#  0.5759624490662,
#  0.5037922871105952,
#  0.5368604110981583,
#  0.5659170461778357,
#  0.49349824333589715,
#  0.5753844612927553,
#  0.5603970251288171,
#  0.44925295406087906,
#  0.5218308593949398,
#  0.4819731524522374,
#  0.5148382200515383,
#  0.48918982928113974,
#  0.4894426115226154,
#  0.525361565694619,
#  0.528415610536311,
#  0.5921640272150107,
#  0.5678979234398003,
#  0.5293175809074481,
#  0.5558943101581544,
#  0.39741486321276687,
#  0.3881048401664141,
#  0.4345677617684001,
#  0.4925224942780253,
#  0.5738189255570658,
#  0.46898573309442754,
#  0.5199209117191639,
#  0.4680494622348599,
#  0.47128472701137314,
#  0.43008602734609225,
#  0.31601828417570943,
#  0.43531343835974035,
#  0.12499710013652968,
#  0.3246040018987027,
#  0.5300468877098814,
#  0.12499710013652968,
#  0.43209052636111134,
#  0.45951340946533686,
#  0.5116747511391482,
#  0.6638915613680438,
#  0.30780800100726113,
#  0.5278838911906755,
#  0.35320059128863124,
#  0.44368887718611416,
#  0.5073486738655084,
#  0.36789087826910694,
#  0.5198155249212546,
#  0.5535729839361706,
#  0.7171137467925297,
#  0.3694390413198777,
#  0.5587142454663216,
#  0.4553485635411225,
#  0.5199097325329027,
#  0.39791325508942677,
#  0.46409197459968643,
#  0.5547128784241331,
#  0.4659739149265157,
#  0.12499710013652968,
#  0.43839149573399006,
#  0.37065732165576665,
#  0.484207462394464,
#  0.41458912382074187,
#  0.507380874567169,
#  0.41098305851666667,
#  0.36936889916713456,
#  0.4326305648072287,
#  0.5055532874605599,
#  0.509322626756434,
#  0.42263065205649203,
#  0.47466982571372124,
#  0.3671507374633803,
#  0.3744053605365276,
#  0.46877926454756585,
#  0.46428273213688864,
#  0.47801686282174083,
#  0.3917951483942884,
#  0.45859160942037736,
#  0.13583689330576093,
#  0.13583689330576093,
#  0.35677730437904254,
#  0.47522931372528665,
#  0.3184277019021254,
#  0.2539774051048572,
#  0.4483751556506646,
#  0.5256513326602006,
#  0.45949290089228506,
#  0.4039882901096973,
#  0.4390654526719846,
#  0.6011231368134409,
#  0.3410649790588044,
#  0.4306161207342005,
#  0.5729788730748713,
#  0.4215627749336779,
#  0.41362271687988006,
#  0.4394260728347721,
#  0.5424810507668,
#  0.37827923209243475,
#  0.4546227792285212,
#  0.4513482773757985,
#  0.33375297893772093,
#  0.37083960222771717,
#  ...]

# %%
x,y,z =0,0,0
for i,j,k in zip(qier,per,lru):
    x += (i-j)/j
    y += (i-k)/k
print(x/len(qier)*100, y/len(per)*100 )
# Out:
# -30.85069990040783 -53.43312873667654

# %%
plt.figure(figsize=(10, 5),dpi=500)
plt.plot(Systemregret_75_qier, marker='o', linestyle='-', color='teal')
plt.title('Original Cost Over Episodes')
plt.xlabel('Steps or Episodes')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler,MinMaxScaler,StandardScaler,QuantileTransformer
import numpy as np
import matplotlib.pyplot as plt

# Convert to 2D array as required by sklearn
Systemregret_array = np.array(Systemregret_75_qier).reshape(-1, 1)

# Apply RobustScaler
scaler = MinMaxScaler()
Systemregret_scaled = scaler.fit_transform(Systemregret_array)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(Systemregret_scaled, marker='o', linestyle='-', color='orange')
plt.title('Cost After Robust Scaling')
plt.xlabel('Steps or Episodes')
plt.ylabel('Scaled Cost')
plt.grid(True)
plt.show()
