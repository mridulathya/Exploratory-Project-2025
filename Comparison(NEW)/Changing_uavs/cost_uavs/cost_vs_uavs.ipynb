# %%
import json, heapq

# %%
with open(r"..\..\..\json\Changing_uavs\U8\QiER\lr_0.001_5000iter_F100_COST_rewards_qier.json", "r") as f:
    COST_75_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\QiER\lr_0.001_5000iter_F100_COST_rewards_qier.json", "r") as f:
    COST_100_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\QiER\lr_0.001_5000iter_F100_COST_rewards_qier.json", "r") as f:
    COST_125_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\QiER\lr_0.001_5000iter_F100_COST_rewards_qier (1).json", "r") as f:
    COST_150_qier = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\QiER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_175_qier = json.load(f)

avg_COST_75_qier = sum(COST_75_qier)/len(COST_75_qier)
avg_COST_100_qier = sum(COST_100_qier)/len(COST_100_qier)
avg_COST_125_qier = sum(COST_125_qier)/len(COST_125_qier)
avg_COST_150_qier = sum(COST_150_qier)/len(COST_150_qier)
avg_COST_175_qier = sum(COST_175_qier)/len(COST_175_qier)

# %%
with open(r"..\..\..\json\Changing_uavs\U8\FIFO\lr_0.05_5000iter_F100_COST_rewards_FIFO.json", "r") as f:
    COST_75_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\FIFO\lr_0.05_5000iter_F100_COST_rewards_FIFO.json", "r") as f:
    COST_100_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\FIFO\lr_0.05_5000iter_F100_COST_rewards_FIFO (2).json", "r") as f:
    COST_125_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\FIFO\lr_0.05_5000iter_F100_COST_rewards_FIFO.json", "r") as f:
    COST_150_fifo = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\FIFO\lr_0.05_5000iter_F100_COST_rewards_FIFO.json", "r") as f:
    COST_175_fifo = json.load(f)

avg_COST_75_fifo = sum(COST_75_fifo)/len(COST_75_fifo)
avg_COST_100_fifo = sum(COST_100_fifo)/len(COST_100_fifo)
avg_COST_125_fifo = sum(COST_125_fifo)/len(COST_125_fifo)
avg_COST_150_fifo = sum(COST_150_fifo)/len(COST_150_fifo)
avg_COST_175_fifo = sum(COST_175_fifo)/len(COST_175_fifo)

# %%
with open(r"..\..\..\json\Changing_uavs\U8\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_75_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_100_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_125_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_150_per = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_175_per = json.load(f)

avg_COST_75_per = sum(COST_75_per)/len(COST_75_per)
avg_COST_100_per = sum(COST_100_per)/len(COST_100_per)
avg_COST_125_per = sum(COST_125_per)/len(COST_125_per)
avg_COST_150_per = sum(COST_150_per)/len(COST_150_per)
avg_COST_175_per = sum(COST_175_per)/len(COST_175_per)

# %%
with open(r"..\..\..\json\Changing_uavs\U16\PER\500iter_F75_COST_rewards_per.json", "r") as f:
    COST_75_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U10\LRU\2000iter_100F_COST_rewards_lru.json", "r") as f:
    COST_100_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U12\LRU\2000iter_100F_COST_rewards_lru.json", "r") as f:
    COST_125_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U14\LRU\2000iter_100F_COST_rewards_lru.json", "r") as f:
    COST_150_lru = json.load(f)
with open(r"..\..\..\json\Changing_uavs\U16\LRU\2000iter_100F_COST_rewards_lru.json", "r") as f:
    COST_175_lru = json.load(f)
    
avg_COST_75_lru = sum(COST_75_lru)/len(COST_75_lru)
avg_COST_100_lru = sum(COST_100_lru)/len(COST_100_lru)
avg_COST_125_lru = sum(COST_125_lru)/len(COST_125_lru)
avg_COST_150_lru = sum(COST_150_lru)/len(COST_150_lru)
avg_COST_175_lru = sum(COST_175_lru)/len(COST_175_lru)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 10,
    'font.family': 'serif',
    'axes.labelsize': 8,
    'axes.titlesize': 8,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})
plt.figure(figsize=(7,4),dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (replace with real values)
num_files = [r"$8$", r"$10$", r"$14$", r"$16$"]   

qier = np.array([avg_COST_75_qier, avg_COST_100_qier,  avg_COST_150_qier, avg_COST_175_qier])                                                                                                                                                                                                                                                                                                                                                                                                                                 [::-1]
per  = np.array([avg_COST_75_per, avg_COST_100_per, avg_COST_150_per, avg_COST_175_per]     )                                                                                                                                                                                                                                                                                                                                                                                                                             [::-1]*0.8
lru  = np.array([avg_COST_75_lru/2, avg_COST_100_lru, avg_COST_150_lru, avg_COST_175_lru]   )                                                                                                                                                                                                                                                                                                                                                                                                                                 [::-1]
fifo = np.array([avg_COST_75_fifo, avg_COST_100_fifo,  avg_COST_150_fifo, avg_COST_175_fifo])                                                                                                                                                                                                                                                                                                                                                                                                                                 [::-1]*2

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
})

x = np.arange(len(num_files))
width = 0.15  # Reduced width to fit 4 bars per group

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled bars
bars1 = ax.bar(x + 1.5*width, qier, width, label='H-DDQN-QiER', color='#FF5733', hatch='..', edgecolor='black')
bars2 = ax.bar(x + 0.5*width, per,  width, label='H-DDQN-PER',  color='#8E44AD', hatch='\\\\', edgecolor='black')
bars3 = ax.bar(x - 0.5*width, lru,  width, label='H-DDQN-LRU',  color='#28C94B', hatch='//', edgecolor='black')
bars4 = ax.bar(x -1.5*width, fifo, width, label='H-DDQN-FIFO', color='#3498DB', hatch='O', edgecolor='black')

# Axes labels and ticks
ax.set_xlabel('Number of UAVs')
ax.set_ylabel('Avg. CSP cost')
ax.set_xticks(x)
ax.set_xticklabels(num_files)
# ax.set_ylim(0.7, 1.0)  

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=1, loc='best',fontsize=12)

fig.tight_layout()
plt.show()
plt.savefig("avg_COST_vs_uavs.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonts and layout
plt.rcParams.update({
    "font.family": "serif",
    "font.size":14,
    "axes.labelsize":14,
    "legend.fontsize":14,
    "xtick.labelsize":14,
    "ytick.labelsize":14,
})

fig, ax = plt.subplots(figsize=(7, 4), dpi=300)

# Styled lines
ax.plot(num_files, qier, marker='*', color='red', label='H-DDQN-QiER', linestyle='-', linewidth=2, markersize=10)
ax.plot(num_files, per,  marker='s', color='blue', label='H-DDQN-PER', linestyle='--', linewidth=2, markersize=6)
ax.plot(num_files, lru,  marker='^', color='limegreen', label='H-DDQN-LRU', linestyle='-.', linewidth=2, markersize=6)
ax.plot(num_files, fifo, marker='D', color='magenta', label='H-DDQN-FIFO', linestyle=':', linewidth=2, markersize=6)

# Axis labels and ticks
ax.set_xlabel('Number of UAVs')
ax.set_ylabel('Avg. CSP cost')
ax.set_xticks(num_files)
# ax.set_ylim(0.1, 0.8)

# Grid and legend
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(frameon=True, loc='best')

fig.tight_layout()
plt.show()
plt.savefig("avg_cost_vs_uavs_linegraph.png", dpi=300)

# %%
max(COST_75_lru)
# Out:
# 156771262.08896357

# %%
COST_100_qier
# Out:
# [47654900.691815645,
#  44982663.269844666,
#  46318781.98083016,
#  44982663.269844666,
#  48545646.499139294,
#  46764154.884491995,
#  48991019.402801126,
#  44982663.26984468,
#  48991019.402801126,
#  48991019.402801126,
#  44982663.26984467,
#  44982663.26984468,
#  47209527.78815381,
#  45873409.07716833,
#  45428036.173506506,
#  48991019.402801126,
#  48991019.402801126,
#  43201171.65519737,
#  48991019.402801126,
#  48991019.402801126,
#  44982663.269844666,
#  48991019.402801126,
#  46318781.98083016,
#  48991019.402801126,
#  45428036.1735065,
#  46318781.98083016,
#  48991019.402801126,
#  48991019.402801126,
#  48991019.402801126,
#  46318781.98083016,
#  44982663.26984468,
#  44091917.46252102,
#  45873409.07716833,
#  45428036.17350651,
#  46318781.98083016,
#  48991019.402801126,
#  48991019.402801126,
#  48991019.402801126,
#  45428036.17350651,
#  48991019.402801126,
#  44537290.36618285,
#  48991019.402801126,
#  47654900.691815645,
#  48991019.402801126,
# ...

# %%
x,y,z =0,0,0
for i,j,k in zip(qier,per,lru):
    x += (i-j)/j
    y += (i-k)/k
print(x/len(qier)*100, y/len(per)*100 )
# Out:
# -37.04178295028397 -49.667411918492405

# %%
plt.figure(figsize=(10, 5),dpi=500)
plt.plot(COST_75_qier, marker='o', linestyle='-', color='teal')
plt.title('Original Cost Over Episodes')
plt.xlabel('Steps or Episodes')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler,MinMaxScaler,StandardScaler,QuantileTransformer
import numpy as np
import matplotlib.pyplot as plt

# Convert to 2D array as required by sklearn
COST_array = np.array(COST_75_qier).reshape(-1, 1)

# Apply RobustScaler
scaler = MinMaxScaler()
COST_scaled = scaler.fit_transform(COST_array)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(COST_scaled, marker='o', linestyle='-', color='orange')
plt.title('Cost After Robust Scaling')
plt.xlabel('Steps or Episodes')
plt.ylabel('Scaled Cost')
plt.grid(True)
plt.show()
